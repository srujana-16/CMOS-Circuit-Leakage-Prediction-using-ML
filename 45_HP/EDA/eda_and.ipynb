# %%
import sys
sys.path.append('../../')
from eda_script import GateEDA

# %%
gate_data_path = "../outputs/simulation_results_and.csv"

# %%
gate_analysis = GateEDA(gate_data_path)

# %%
gate_analysis.data_exploration()
# Out:
# Data Shape: (80000, 20)
# Column Names: Index(['Vin_A', 'Vin_B', 'Vin_C', 'temp', 'pvdd', 'cqload', 'lmin', 'wmin',
#        'toxe_n', 'toxm_n', 'toxref_n', 'toxe_p', 'toxm_p', 'toxref_p',
#        'toxp_par', 'xj_n', 'xj_p', 'ndep_n', 'ndep_p', 'leakage'],
#       dtype='object')
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Vin_A     80000 non-null  float64
#  1   Vin_B     80000 non-null  float64
#  2   Vin_C     80000 non-null  float64
#  3   temp      80000 non-null  float64
#  4   pvdd      80000 non-null  float64
#  5   cqload    80000 non-null  float64
#  6   lmin      80000 non-null  float64
#  7   wmin      80000 non-null  float64
#  8   toxe_n    80000 non-null  float64
#  9   toxm_n    80000 non-null  float64
#  10  toxref_n  80000 non-null  float64
#  11  toxe_p    80000 non-null  float64
# ...

# %%
gate_analysis.data_cleaning()
# Out:
# Missing Values:
#  Vin_A       0
# Vin_B       0
# Vin_C       0
# temp        0
# pvdd        0
# cqload      0
# lmin        0
# wmin        0
# toxe_n      0
# toxm_n      0
# toxref_n    0
# toxe_p      0
# toxm_p      0
# toxref_p    0
# toxp_par    0
# xj_n        0
# xj_p        0
# ndep_n      0
# ndep_p      0
# leakage     0
# dtype: int64
# Duplicates: 0

# %%
gate_analysis.preprocessing()
# Out:
# Data types after preprocessing:
# Vin_A         int64
# Vin_B         int64
# Vin_C       float64
# temp        float64
# pvdd        float64
# cqload      float64
# lmin        float64
# wmin        float64
# toxe_n      float64
# toxm_n      float64
# toxref_n    float64
# toxe_p      float64
# toxm_p      float64
# toxref_p    float64
# toxp_par    float64
# xj_n        float64
# xj_p        float64
# ndep_n      float64
# ndep_p      float64
# leakage     float64
# dtype: object

# %%
gate_analysis.scaling()

# %%
gate_analysis.data_visualization()
# Out:
# /home/sruj/miniconda3/envs/env/lib/python3.12/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/sruj/miniconda3/envs/env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/sruj/miniconda3/envs/env/lib/python3.12/site-packages/seaborn/_oldcore.py:1498: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
gate_analysis.scatter_plot('toxe_p', 'leakage', 'Oxide Thickness', 'Leakage', '2D plot: Leakage vs Tox')

# %%
gate_analysis.pca_analysis()
# Out:
# Explained Variance Ratio:
# [0.09107923 0.05236656 0.05213834]

# %%
gate_analysis.pca_corr()

# %%
gate_analysis.most_correlated()
# Out:
# Most Correlated with PCA_1:
# PCA_1    1.000000e+00
# PCA_3    3.017712e-17
# PCA_2    2.844619e-17
# Name: PCA_1, dtype: float64
#
# Most Correlated with PCA_2:
# PCA_2    1.000000e+00
# PCA_3    5.783676e-17
# PCA_1    2.844619e-17
# Name: PCA_2, dtype: float64
#
# Most Correlated with PCA_3:
# PCA_3    1.000000e+00
# PCA_2    5.783676e-17
# PCA_1    3.017712e-17
# Name: PCA_3, dtype: float64

# %%
gate_analysis.plot_pca()

# %%
gate_analysis.plot_pca_3d()

# %%
gate_analysis.pattern_mining()
# Out:
# /home/sruj/miniconda3/envs/env/lib/python3.12/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
gate_analysis.correlation_analysis()

# %%
gate_analysis.vif_analysis()
# Out:
# VIF Scores:
#      feature       VIF
# 0      Vin_A  1.864954
# 1      Vin_B  1.101362
# 2      Vin_C  1.000257
# 3       temp  1.236413
# 4       pvdd  1.246246
# 5     cqload  1.001244
# 6       lmin  1.005978
# 7       wmin  1.005418
# 8     toxe_n  1.531155
# 9     toxm_n  1.001200
# 10  toxref_n  1.004170
# 11    toxe_p  1.033574
# 12    toxm_p  1.001153
# 13  toxref_p  1.001882
# 14  toxp_par  1.001808
# 15      xj_n  1.001435
# 16      xj_p  1.000967
# 17    ndep_n  1.000800
# 18    ndep_p  1.001511
# 19   leakage  3.027146
