# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "../outputs/simulation_results_and.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Vin_A  Vin_B  Vin_C       temp      pvdd        cqload          lmin  \
# 0    0.0    0.0    0.0  43.786431  1.049654  1.992558e-16  4.422860e-08
# 1    0.0    0.0    1.0  43.786431  1.049654  1.992558e-16  4.422860e-08
# 2    0.0    1.0    0.0  43.786431  1.049654  1.992558e-16  4.422860e-08
# 3    0.0    1.0    1.0  43.786431  1.049654  1.992558e-16  4.422860e-08
# 4    1.0    0.0    0.0  43.786431  1.049654  1.992558e-16  4.422860e-08
#
#            wmin        toxe_n        toxm_n      toxref_n        toxe_p  \
# 0  4.335549e-08  8.858098e-10  9.149308e-10  8.800085e-10  9.382331e-10
# 1  4.335549e-08  8.858098e-10  9.149308e-10  8.800085e-10  9.382331e-10
# 2  4.335549e-08  8.858098e-10  9.149308e-10  8.800085e-10  9.382331e-10
# 3  4.335549e-08  8.858098e-10  9.149308e-10  8.800085e-10  9.382331e-10
# 4  4.335549e-08  8.858098e-10  9.149308e-10  8.800085e-10  9.382331e-10
#
#          toxm_p      toxref_p      toxp_par          xj_n          xj_p  \
# ...

# %%
df.describe()
# Out:
#               Vin_A         Vin_B         Vin_C          temp          pvdd  \
# count  80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.500000      0.500000      0.500000     34.362600      0.999048
# std        0.500003      0.500003      0.500003     52.126724      0.058258
# min        0.000000      0.000000      0.000000    -54.986959      0.900033
# 25%        0.000000      0.000000      0.000000    -10.844191      0.948592
# 50%        0.500000      0.500000      0.500000     33.830185      0.998653
# 75%        1.000000      1.000000      1.000000     79.692719      1.049947
# max        1.000000      1.000000      1.000000    124.996031      1.099992
#
#              cqload          lmin          wmin        toxe_n        toxm_n  \
# count  8.000000e+04  8.000000e+04  8.000000e+04  8.000000e+04  8.000000e+04
# mean   2.511981e-15  4.503877e-08  4.500441e-08  9.002687e-10  8.996303e-10
# ...

# %%
df.isnull().sum()
# Out:
# Vin_A       0
# Vin_B       0
# Vin_C       0
# temp        0
# pvdd        0
# cqload      0
# lmin        0
# wmin        0
# toxe_n      0
# toxm_n      0
# toxref_n    0
# toxe_p      0
# toxm_p      0
# toxref_p    0
# toxp_par    0
# xj_n        0
# xj_p        0
# ndep_n      0
# ndep_p      0
# leakage     0
# dtype: int64
