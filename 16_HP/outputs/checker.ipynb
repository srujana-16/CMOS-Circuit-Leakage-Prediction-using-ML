# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "../outputs/simulation_results_xor_delay.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Vin_A  Vin_B       temp      pvdd        cqload          lmin  \
# 0    0.0    0.0  43.786431  0.962359  1.255213e-15  4.160451e-08
# 1    0.0    1.0  43.786431  0.962359  1.255213e-15  4.160451e-08
# 2    1.0    0.0  43.786431  0.962359  1.255213e-15  4.160451e-08
# 3    1.0    1.0  43.786431  0.962359  1.255213e-15  4.160451e-08
# 4    0.0    0.0  73.734086  1.039269  1.145076e-15  4.556253e-08
#
#            wmin        toxe_n        toxm_n      toxref_n  ...      toxref_p  \
# 0  4.583257e-08  9.208132e-10  8.646253e-10  9.379523e-10  ...  8.681006e-10
# 1  4.583257e-08  9.208132e-10  8.646253e-10  9.379523e-10  ...  8.681006e-10
# 2  4.583257e-08  9.208132e-10  8.646253e-10  9.379523e-10  ...  8.681006e-10
# 3  4.583257e-08  9.208132e-10  8.646253e-10  9.379523e-10  ...  8.681006e-10
# 4  4.598389e-08  8.952128e-10  9.390428e-10  9.063449e-10  ...  9.423666e-10
#
#        toxp_par          xj_n          xj_p        ndep_n        ndep_p  \
# ...

# %%
df.describe()
# Out:
#             Vin_A       Vin_B        temp        pvdd        cqload  \
# count  800.000000  800.000000  800.000000  800.000000  8.000000e+02
# mean     0.500000    0.500000   35.078804    0.998239  2.369370e-15
# std      0.500313    0.500313   51.136448    0.058810  1.382998e-15
# min      0.000000    0.000000  -54.154814    0.902285  1.036152e-17
# 25%      0.000000    0.000000   -9.611742    0.948125  1.149621e-15
# 50%      0.500000    0.500000   42.246439    0.992343  2.223349e-15
# 75%      1.000000    1.000000   73.785289    1.051436  3.461702e-15
# max      1.000000    1.000000  124.792461    1.098068  4.978706e-15
#
#                lmin          wmin        toxe_n        toxm_n      toxref_n  \
# count  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02
# mean   4.490405e-08  4.494106e-08  8.968601e-10  8.955074e-10  8.972368e-10
# std    1.428107e-09  1.392229e-09  2.952266e-11  3.071231e-11  2.789551e-11
# ...

# %%
df.isnull().sum()
# Out:
# Vin_A             0
# Vin_B             0
# temp              0
# pvdd              0
# cqload            0
# lmin              0
# wmin              0
# toxe_n            0
# toxm_n            0
# toxref_n          0
# toxe_p            0
# toxm_p            0
# toxref_p          0
# toxp_par          0
# xj_n              0
# xj_p              0
# ndep_n            0
# ndep_p            0
# delay_LH_NodeA    0
# delay_HL_NodeA    0
# delay_LH_NodeB    0
# delay_HL_NodeB    0
# dtype: int64
